# %%
# !pip install --upgrade diffusers transforms -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 47.9 MB/s eta 0:00:00

# %%
from pathlib import Path

import tqdm

import torch

import pandas as pd

import numpy as np

from diffusers import StableDiffusionPipeline

from transformers import pipeline, set_seed

import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

import cv2

# %%
import torch

# %%
class bird:

  device = "cuda"
  seed = 42
  generator = torch.Generator(device).manual_seed(seed)
  image_gen_steps = 35
  image_gen_model_id = "stabilityai/stable-diffusion-2"
  image_gen_size = (400,400)
  image_gen_guidance_scale =9
  prompt_gen_model_id = "gpt2"
  prompt_dataset_size = 6
  prompt_max_length=12

# %%
from diffusers import StableDiffusionPipeline

# %%
image_gen_model = StableDiffusionPipeline.from_pretrained(
    bird.image_gen_model_id,
    torch_dtype=torch.float16,
    revisions="fp16",
    use_auth_token='hf_JoukMetFipewnIK11oFzDS3HVHIQeswXzH'
)


image_gen_model = image_gen_model.to(bird.device)
# Out:
# Keyword arguments {'revisions': 'fp16', 'use_auth_token': 'hf_JoukMetFipewnIK11oFzDS3HVHIQeswXzH'} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def generate_image(prompt, model):

   image = model(

   prompt, num_inference_steps=bird.image_gen_steps,
   generator=bird.generator,

   guidance_scale=bird.image_gen_guidance_scale
   ).images[0]

   image = image.resize(bird.image_gen_size)

   return image

# %%
generate_image("A bird with yellow wings", image_gen_model)
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=400x400>
